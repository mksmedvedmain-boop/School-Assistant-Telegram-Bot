# %% [markdown]
# <a href="https://colab.research.google.com/github/mksmedvedmain-boop/Telegram-bot/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pyTelegramBotAPI
# Out:
# Collecting pyTelegramBotAPI
#   Downloading pytelegrambotapi-4.34.0-py3-none-any.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.3/48.3 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from pyTelegramBotAPI) (3.14.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from pyTelegramBotAPI) (2.32.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->pyTelegramBotAPI) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->pyTelegramBotAPI) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->pyTelegramBotAPI) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->pyTelegramBotAPI) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->pyTelegramBotAPI) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->pyTelegramBotAPI) (0.5.2)
# Requirement already satisfied: typing_extensions>=4.4 in /usr/local/lib/python3.12/dist-packages (from aiohttp->pyTelegramBotAPI) (4.15.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->pyTelegramBotAPI) (1.24.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->pyTelegramBotAPI) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->pyTelegramBotAPI) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->pyTelegramBotAPI) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->pyTelegramBotAPI) (2026.5.20)
# Downloading pytelegrambotapi-4.34.0-py3-none-any.whl (317 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.2/317.2 kB 9.7 MB/s eta 0:00:00
# Installing collected packages: pyTelegramBotAPI
# Successfully installed pyTelegramBotAPI-4.34.0

# %%
import git
# !git branch
# !git status
import telebot
import webbrowser
from telebot import types
import sqlite3

TOKEN = '7772114816:AAGMW8N6k4iY6s6U0-sIsODjdBsztzhKr2w'

bot = telebot.TeleBot('7772114816:AAGMW8N6k4iY6s6U0-sIsODjdBsztzhKr2w')

name = None

subjects = {
    "История",
    "Русский язык",
    "Английский язык",
    "Математика",
    "География",
    "Физика",
    "Биология",
    "Химия",
    "Информатика",
    "ОБЗР",
    "Литература",
    "Труд",
    "Обществознание"
}

# Учителя
teachers = {
    "История": ["Ольга Викторовна", "Елена Александровна"],
    "Русский язык": ["Юлия Викторовна", "Мария Павловна", "Галина Дмитриевна"],
    "Математика": ["Светлана Владимировна", "Юлия Александровна", "Анастасия Сергеевна", "Ирина Ивановна"],
    "Физика": ["Светлана Владимировна", "Алена Игоревна"],
    "Английский язык": ["Наталья Олеговна", "Ирина Николаевна", "Надежда Петровна", "Надежда Алексеевна"],
    "Биология": ["Виктория Сергеевна", "Татьяна Юревна"],  # Исправлено "Юревьана" -> "Юревна"
    "ОБЗР": ["Алексей Юрьевич", "Денис Валерьевич"],
    "Информатика": ["Александра Ивановна", "Вячеслав Викторович"],
    "География": ["Татьяна Юревна"],
    "Химия": ["Николай Евгеньевич"],
    "Труд": ["Роман Викторович"],
    "Литература": ["Юлия Викторовна", "Мария Павловна", "Галина Дмитриевна"],
    "Обществознание": ["Елена Александровна", "Ольга Викторовна"]
}

# Кабинеты
cabinets = {
    "Алена Игоревна": "Кабинет 510",
    "Александра Ивановна": "Кабинет 109",
    "Юлия Викторовна": "Кабинет 410",
    "Мария Павловна": "Кабинет 305",
    "Галина Дмитриевна": "Кабинет 308",
    "Светлана Владимировна": "Кабинет 512",
    "Юлия Александровна": "Кабинет 401",
    "Анастасия Сергеевна": "Кабинет 404",
    "Виктория Сергеевна": "Кабинет 510 или 502",
    "Алексей Юрьевич": "Кабинет 307",
    "Вячеслав Викторович": "Кабинет 405",
    "Елена Александровна": "501",
    "Ольга Викторовна": "409",
    "Роман Викторович": "502",
    "Николай Евгеньевич": "510",
    "Татьяна Юревна": "510",
    "Денис Валерьевич": "410 или 510",
    "Надежда Петровна": "311",
    "Наталья Олеговна": "209",
    "Ирина Николаевна": "307",
    "Надежда Алексеевна": "412",
    "Ирина Ивановна": "402"
}

# 📌 Функция для меню (чтобы не дублировать код)
def subjects_menu():
    markup = types.InlineKeyboardMarkup()

    markup.row(
        types.InlineKeyboardButton("История", callback_data="История"),
        types.InlineKeyboardButton("Русский язык", callback_data="Русский язык")
    )
    markup.row(
        types.InlineKeyboardButton("Английский язык", callback_data="Английский язык"),
        types.InlineKeyboardButton("Математика", callback_data="Математика")
    )
    markup.row(
        types.InlineKeyboardButton("География", callback_data="География"),
        types.InlineKeyboardButton("Физика", callback_data="Физика")
    )
    markup.row(
        types.InlineKeyboardButton("Биология", callback_data="Биология"),
        types.InlineKeyboardButton("Химия", callback_data="Химия")
    )
    markup.row(
        types.InlineKeyboardButton("Информатика", callback_data="Информатика"),
        types.InlineKeyboardButton("ОБЗР", callback_data="ОБЗР")
    )
    markup.row(
        types.InlineKeyboardButton("Литература", callback_data="Литература"),
        types.InlineKeyboardButton("Труд", callback_data="Труд"),
        types.InlineKeyboardButton("Обществознание", callback_data="Обществознание")
    )
    markup.row(types.InlineKeyboardButton("📚 Шпаргалки", callback_data="cheats"))

    return markup

# ▶️ СТАРТ
@bot.message_handler(commands=['start'])
def start(message):
    user_name = message.from_user.first_name  # имя пользователя

    bot.send_message(
        message.chat.id,
        f"👋 Привет, {user_name}!\n\nВыбери предмет:",
        reply_markup=subjects_menu()
    )

# 🔘 ОБРАБОТКА КНОПОК
@bot.callback_query_handler(func=lambda call: True)
def callback(call):
    data = call.data

    # 📚 Шпаргалки
    if data == "cheats":
        markup = types.InlineKeyboardMarkup()
        markup.row(types.InlineKeyboardButton("🌐 Открыть сайт", url='https://webium.ru/media/material/'))
        markup.row(types.InlineKeyboardButton("⬅️ Назад", callback_data="back"))

        bot.edit_message_text(
            f"📚 Шпаргалки:\n\n{'https://webium.ru/media/material/'}",
            chat_id=call.message.chat.id,
            message_id=call.message.message_id,
            reply_markup=markup
        )

    # 📘 Предмет
    elif data in teachers:
        markup = types.InlineKeyboardMarkup()

        for teacher in teachers[data]:
            markup.row(types.InlineKeyboardButton(f"👨‍🏫 {teacher}", callback_data=teacher))

        markup.row(types.InlineKeyboardButton("⬅️ Назад", callback_data="back"))

        bot.edit_message_text(
            f"📘 {data}\nВыберите преподавателя:",
            chat_id=call.message.chat.id,
            message_id=call.message.message_id,
            reply_markup=markup
        )

    # 👨‍🏫 Учитель
    elif data in cabinets:
        markup = types.InlineKeyboardMarkup()
        markup.row(types.InlineKeyboardButton("⬅️ Назад", callback_data="back"))

        bot.edit_message_text(
            f"👨‍🏫 {data}\n📍 {cabinets[data]}",
            chat_id=call.message.chat.id,
            message_id=call.message.message_id,
            reply_markup=markup
        )

    # 🔙 Назад
    elif data == "back":
        bot.edit_message_text(
            "Выбери предмет:",
            chat_id=call.message.chat.id,
            message_id=call.message.message_id,
            reply_markup=subjects_menu()
        )

    # ⚠️ Ошибка
    else:
        bot.answer_callback_query(call.id, "Ошибка выбора")

bot.polling(none_stop=True)
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
pip install pyTelegramBotAPI
# Out:
# Collecting pyTelegramBotAPI
#   Downloading pytelegrambotapi-4.33.0-py3-none-any.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.3/48.3 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from pyTelegramBotAPI) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->pyTelegramBotAPI) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->pyTelegramBotAPI) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->pyTelegramBotAPI) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->pyTelegramBotAPI) (2026.2.25)
# Downloading pytelegrambotapi-4.33.0-py3-none-any.whl (308 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.4/308.4 kB 7.6 MB/s eta 0:00:00
# Installing collected packages: pyTelegramBotAPI
# Successfully installed pyTelegramBotAPI-4.33.0
